# %%
import random
import pickle

import numpy as np
import pandas as pd
from nltk.tokenize import RegexpTokenizer

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import LSTM, Dense, Activation
from tensorflow.keras.optimizers import RMSprop
# Out:
# /Users/barraharrison/Desktop/2025 Coding/Text-Generation-And-Prediction/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
text_data_frame = pd.read_csv("fake_or_real_news.csv")

# %%
text_data_frame
# Out:
#          id                                              title  \
# 0      8476                       You Can Smell Hillary’s Fear
# 1     10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2      3608        Kerry to go to Paris in gesture of sympathy
# 3     10142  Bernie supporters on Twitter erupt in anger ag...
# 4       875   The Battle of New York: Why This Primary Matters
# ...     ...                                                ...
# 6330   4490  State Department says it can't find emails fro...
# 6331   8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332   8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333   4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334   4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2     U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3     — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4     It's primary day in New York and front-runners...  REAL
# ...                                                 ...   ...
# 6330  The State Department told the Republican Natio...  REAL
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...  FAKE
# 6332   Anti-Trump Protesters Are Tools of the Oligar...  FAKE
# 6333  ADDIS ABABA, Ethiopia —President Obama convene...  REAL
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...  REAL
#
# [6335 rows x 4 columns]

# %%
text = list(text_data_frame.text.values)
joined_text = " ".join(text)

# %%
partial_text = joined_text[:10000]

# %%
tokenizer = RegexpTokenizer(r"\w+")
tokens = tokenizer.tokenize(partial_text.lower())

# %%
unique_tokens = np.unique(tokens)
unique_token_index = {token: idx for idx, token in enumerate(unique_tokens)}

# %%
unique_token_index
# Out:
# {np.str_('2016'): 0,
#  np.str_('2020'): 1,
#  np.str_('5'): 2,
#  np.str_('60'): 3,
#  np.str_('a'): 4,
#  np.str_('abc'): 5,
#  np.str_('abcpolitics'): 6,
#  np.str_('abedin'): 7,
#  np.str_('about'): 8,
#  np.str_('aboutface'): 9,
#  np.str_('abuses'): 10,
#  np.str_('accused'): 11,
#  np.str_('accusing'): 12,
#  np.str_('act'): 13,
#  np.str_('ad'): 14,
#  np.str_('admits'): 15,
#  np.str_('ads'): 16,
#  np.str_('afraid'): 17,
#  np.str_('after'): 18,
#  np.str_('afternoon'): 19,
#  np.str_('against'): 20,
#  np.str_('age'): 21,
#  np.str_('agency'): 22,
#  np.str_('agents'): 23,
#  np.str_('ago'): 24,
#  np.str_('ahead'): 25,
#  np.str_('alive'): 26,
#  np.str_('all'): 27,
#  np.str_('allegations'): 28,
#  np.str_('allies'): 29,
#  np.str_('allowed'): 30,
#  np.str_('already'): 31,
#  np.str_('also'): 32,
#  np.str_('amendment'): 33,
#  np.str_('americans'): 34,
#  np.str_('an'): 35,
#  np.str_('and'): 36,
#  np.str_('announced'): 37,
#  np.str_('anthony'): 38,
#  np.str_('any'): 39,
#  np.str_('anywhere'): 40,
#  np.str_('apolitical'): 41,
#  np.str_('appearance'): 42,
#  np.str_('appeared'): 43,
#  np.str_('appearing'): 44,
#  np.str_('appeaser'): 45,
#  np.str_('approach'): 46,
#  np.str_('are'): 47,
#  np.str_('around'): 48,
#  np.str_('arrogant'): 49,
#  np.str_('article'): 50,
#  np.str_('as'): 51,
#  np.str_('asked'): 52,
#  np.str_('assault'): 53,
#  np.str_('assaulting'): 54,
#  np.str_('assaults'): 55,
#  np.str_('associates'): 56,
#  np.str_('assume'): 57,
#  np.str_('at'): 58,
#  np.str_('attack'): 59,
#  np.str_('attacked'): 60,
#  np.str_('attacking'): 61,
#  np.str_('away'): 62,
#  np.str_('awkward'): 63,
#  np.str_('awkwardly'): 64,
#  np.str_('back'): 65,
#  np.str_('backed'): 66,
#  np.str_('bad'): 67,
#  np.str_('badly'): 68,
#  np.str_('batch'): 69,
#  np.str_('bathroom'): 70,
#  np.str_('be'): 71,
#  np.str_('becoming'): 72,
#  np.str_('beds'): 73,
#  np.str_('been'): 74,
#  np.str_('before'): 75,
#  np.str_('behavior'): 76,
#  np.str_('behind'): 77,
#  np.str_('being'): 78,
#  np.str_('belief'): 79,
#  np.str_('believes'): 80,
#  np.str_('believing'): 81,
#  np.str_('better'): 82,
#  np.str_('between'): 83,
#  np.str_('bigger'): 84,
#  np.str_('bigotry'): 85,
#  np.str_('bizarre'): 86,
#  np.str_('boldly'): 87,
#  np.str_('born'): 88,
#  np.str_('boston'): 89,
#  np.str_('bragged'): 90,
#  np.str_('breathing'): 91,
#  np.str_('breeze'): 92,
#  np.str_('breezy'): 93,
#  np.str_('bribery'): 94,
#  np.str_('bring'): 95,
#  np.str_('bureau'): 96,
#  np.str_('buried'): 97,
#  np.str_('but'): 98,
#  np.str_('by'): 99,
#  np.str_('cable'): 100,
#  np.str_('calling'): 101,
#  np.str_('came'): 102,
#  np.str_('campaign'): 103,
#  np.str_('can'): 104,
#  np.str_('candidate'): 105,
#  np.str_('cards'): 106,
#  np.str_('career'): 107,
#  np.str_('careers'): 108,
#  np.str_('carville'): 109,
#  np.str_('center'): 110,
#  np.str_('chances'): 111,
#  np.str_('changed'): 112,
#  np.str_('charge'): 113,
#  np.str_('chilly'): 114,
#  np.str_('circulated'): 115,
#  np.str_('claim'): 116,
#  np.str_('claimed'): 117,
#  np.str_('claiming'): 118,
#  np.str_('classified'): 119,
#  np.str_('clearly'): 120,
#  np.str_('clinton'): 121,
#  np.str_('clintons'): 122,
#  np.str_('clintonworld'): 123,
#  np.str_('close'): 124,
#  np.str_('closing'): 125,
#  np.str_('cnn'): 126,
#  np.str_('co'): 127,
#  np.str_('collapsed'): 128,
#  np.str_('colleagues'): 129,
#  np.str_('column'): 130,
#  np.str_('com'): 131,
#  np.str_('coma'): 132,
#  np.str_('come'): 133,
#  np.str_('comey'): 134,
#  np.str_('comment'): 135,
#  np.str_('compared'): 136,
#  np.str_('computer'): 137,
#  np.str_('confident'): 138,
#  np.str_('conservative'): 139,
#  np.str_('conspiracies'): 140,
#  np.str_('conspiracy'): 141,
#  np.str_('continue'): 142,
#  np.str_('control'): 143,
#  np.str_('conviction'): 144,
#  np.str_('coordinating'): 145,
#  np.str_('corrected'): 146,
#  np.str_('corruption'): 147,
#  np.str_('could'): 148,
#  np.str_('couldn'): 149,
#  np.str_('countless'): 150,
#  np.str_('country'): 151,
#  np.str_('courage'): 152,
#  np.str_('course'): 153,
#  np.str_('cover'): 154,
#  np.str_('covert'): 155,
#  np.str_('cowardice'): 156,
#  np.str_('coy'): 157,
#  np.str_('cravenly'): 158,
#  np.str_('credibility'): 159,
#  np.str_('crime'): 160,
#  np.str_('criminal'): 161,
#  np.str_('cunning'): 162,
#  np.str_('currently'): 163,
#  np.str_('cycle'): 164,
#  np.str_('damaging'): 165,
#  np.str_('daniel'): 166,
#  np.str_('day'): 167,
#  np.str_('days'): 168,
#  np.str_('debate'): 169,
#  np.str_('decided'): 170,
#  np.str_('decides'): 171,
#  np.str_('declare'): 172,
#  np.str_('declared'): 173,
#  np.str_('declaring'): 174,
#  np.str_('defending'): 175,
#  np.str_('delicious'): 176,
#  np.str_('democratic'): 177,
#  np.str_('democrats'): 178,
#  np.str_('denial'): 179,
#  np.str_('deny'): 180,
#  np.str_('desperate'): 181,
#  np.str_('desperately'): 182,
#  np.str_('desperation'): 183,
#  np.str_('destroy'): 184,
#  np.str_('development'): 185,
#  np.str_('did'): 186,
#  np.str_('didn'): 187,
#  np.str_('digg'): 188,
#  np.str_('director'): 189,
#  np.str_('display'): 190,
#  np.str_('dnc'): 191,
#  np.str_('do'): 192,
#  np.str_('doj'): 193,
#  np.str_('don'): 194,
#  np.str_('done'): 195,
#  np.str_('dosed'): 196,
#  np.str_('down'): 197,
#  np.str_('during'): 198,
#  np.str_('edgar'): 199,
#  np.str_('editorial'): 200,
#  np.str_('either'): 201,
#  np.str_('elect'): 202,
#  np.str_('election'): 203,
#  np.str_('else'): 204,
#  np.str_('email'): 205,
#  np.str_('emailing'): 206,
#  np.str_('emails'): 207,
#  np.str_('endorsement'): 208,
#  np.str_('energy'): 209,
#  np.str_('enjoys'): 210,
#  np.str_('enough'): 211,
#  np.str_('entire'): 212,
#  np.str_('especially'): 213,
#  np.str_('establishment'): 214,
#  np.str_('even'): 215,
#  np.str_('ever'): 216,
#  np.str_('every'): 217,
#  np.str_('everyone'): 218,
#  np.str_('exactly'): 219,
#  np.str_('example'): 220,
#  np.str_('exist'): 221,
#  np.str_('existence'): 222,
#  np.str_('explanation'): 223,
#  np.str_('explanations'): 224,
#  np.str_('explosively'): 225,
#  np.str_('exposed'): 226,
#  np.str_('exposing'): 227,
#  np.str_('fairly'): 228,
#  np.str_('fbi'): 229,
#  np.str_('fear'): 230,
#  np.str_('federal'): 231,
#  np.str_('feigned'): 232,
#  np.str_('fellow'): 233,
#  np.str_('few'): 234,
#  np.str_('fight'): 235,
#  np.str_('fighting'): 236,
#  np.str_('figurehead'): 237,
#  np.str_('filled'): 238,
#  np.str_('film'): 239,
#  np.str_('final'): 240,
#  np.str_('finding'): 241,
#  np.str_('fire'): 242,
#  np.str_('fireworks'): 243,
#  np.str_('flailing'): 244,
#  np.str_('focused'): 245,
#  np.str_('focusing'): 246,
#  np.str_('followed'): 247,
#  np.str_('for'): 248,
#  np.str_('form'): 249,
#  np.str_('foundation'): 250,
#  np.str_('freedom'): 251,
#  np.str_('from'): 252,
#  np.str_('front'): 253,
#  np.str_('fundamental'): 254,
#  np.str_('futures'): 255,
#  np.str_('gasoline'): 256,
#  np.str_('gave'): 257,
#  np.str_('given'): 258,
#  np.str_('glancing'): 259,
#  np.str_('globe'): 260,
#  np.str_('go'): 261,
#  np.str_('going'): 262,
#  np.str_('gone'): 263,
#  np.str_('good'): 264,
#  np.str_('google'): 265,
#  np.str_('got'): 266,
#  np.str_('greenfield'): 267,
#  np.str_('hacks'): 268,
#  np.str_('had'): 269,
#  np.str_('happened'): 270,
#  np.str_('hard'): 271,
#  np.str_('harry'): 272,
#  np.str_('has'): 273,
#  np.str_('hatch'): 274,
#  np.str_('hates'): 275,
#  np.str_('have'): 276,
#  np.str_('he'): 277,
#  np.str_('head'): 278,
#  np.str_('headline'): 279,
#  np.str_('hell'): 280,
#  np.str_('her'): 281,
#  np.str_('here'): 282,
#  np.str_('hillary'): 283,
#  np.str_('him'): 284,
#  np.str_('himself'): 285,
#  np.str_('his'): 286,
#  np.str_('hit'): 287,
#  np.str_('home'): 288,
#  np.str_('hoover'): 289,
#  np.str_('hope'): 290,
#  np.str_('hospital'): 291,
#  np.str_('hour'): 292,
#  np.str_('house'): 293,
#  np.str_('how'): 294,
#  np.str_('however'): 295,
#  np.str_('https'): 296,
#  np.str_('hubris'): 297,
#  np.str_('huma'): 298,
#  np.str_('hurt'): 299,
#  np.str_('idea'): 300,
#  np.str_('if'): 301,
#  np.str_('illegal'): 302,
#  np.str_('illegality'): 303,
#  np.str_('impropriety'): 304,
#  np.str_('in'): 305,
#  np.str_('information'): 306,
#  np.str_('insane'): 307,
#  np.str_('insisted'): 308,
#  np.str_('instant'): 309,
#  np.str_('instead'): 310,
#  np.str_('interesting'): 311,
#  np.str_('intimidation'): 312,
#  np.str_('into'): 313,
#  np.str_('investigation'): 314,
#  np.str_('investigators'): 315,
#  np.str_('irritating'): 316,
#  np.str_('is'): 317,
#  np.str_('islam'): 318,
#  np.str_('isn'): 319,
#  np.str_('it'): 320,
#  np.str_('its'): 321,
#  np.str_('j'): 322,
#  np.str_('james'): 323,
#  np.str_('jobs'): 324,
#  np.str_('journalism'): 325,
#  np.str_('just'): 326,
#  np.str_('justified'): 327,
#  np.str_('keep'): 328,
#  np.str_('keeping'): 329,
#  np.str_('kgb'): 330,
#  np.str_('kind'): 331,
#  np.str_('knew'): 332,
#  np.str_('know'): 333,
#  np.str_('lambasting'): 334,
#  np.str_('lash'): 335,
#  np.str_('last'): 336,
#  np.str_('latest'): 337,
#  np.str_('lead'): 338,
#  np.str_('leadership'): 339,
#  np.str_('leave'): 340,
#  np.str_('led'): 341,
#  np.str_('left'): 342,
#  np.str_('letter'): 343,
#  np.str_('level'): 344,
#  np.str_('lie'): 345,
#  np.str_('lies'): 346,
#  np.str_('like'): 347,
#  np.str_('limp'): 348,
#  np.str_('linkedin'): 349,
#  np.str_('lit'): 350,
#  np.str_('lived'): 351,
#  np.str_('loaded'): 352,
#  np.str_('locked'): 353,
#  np.str_('lofty'): 354,
#  np.str_('long'): 355,
#  np.str_('longer'): 356,
#  np.str_('look'): 357,
#  np.str_('lot'): 358,
#  np.str_('loyalists'): 359,
#  np.str_('lunatic'): 360,
#  np.str_('lynch'): 361,
#  np.str_('made'): 362,
#  np.str_('major'): 363,
#  np.str_('make'): 364,
#  np.str_('making'): 365,
#  np.str_('man'): 366,
#  np.str_('manages'): 367,
#  np.str_('many'): 368,
#  np.str_('match'): 369,
#  np.str_('may'): 370,
#  np.str_('meant'): 371,
#  np.str_('media'): 372,
#  np.str_('mess'): 373,
#  np.str_('might'): 374,
#  np.str_('miles'): 375,
#  np.str_('misguided'): 376,
#  np.str_('mob'): 377,
#  np.str_('moment'): 378,
#  np.str_('months'): 379,
#  np.str_('moral'): 380,
#  np.str_('more'): 381,
#  np.str_('most'): 382,
#  np.str_('msnbc'): 383,
#  np.str_('much'): 384,
#  np.str_('mysterious'): 385,
#  np.str_('navigate'): 386,
#  np.str_('near'): 387,
#  np.str_('never'): 388,
#  np.str_('new'): 389,
#  np.str_('news'): 390,
#  np.str_('nice'): 391,
#  np.str_('no'): 392,
#  np.str_('nobody'): 393,
#  np.str_('nominee'): 394,
#  np.str_('nonsense'): 395,
#  np.str_('not'): 396,
#  np.str_('nothing'): 397,
#  np.str_('november'): 398,
#  np.str_('now'): 399,
#  np.str_('numerous'): 400,
#  np.str_('obama'): 401,
#  np.str_('of'): 402,
#  np.str_('off'): 403,
#  np.str_('often'): 404,
#  np.str_('old'): 405,
#  np.str_('on'): 406,
#  np.str_('once'): 407,
#  np.str_('one'): 408,
#  np.str_('only'): 409,
#  np.str_('operation'): 410,
#  np.str_('opponent'): 411,
#  np.str_('option'): 412,
#  np.str_('or'): 413,
#  np.str_('original'): 414,
#  np.str_('other'): 415,
#  np.str_('ought'): 416,
#  np.str_('out'): 417,
#  np.str_('outcome'): 418,
#  np.str_('outdone'): 419,
#  np.str_('over'): 420,
#  np.str_('own'): 421,
#  np.str_('panicked'): 422,
#  np.str_('paranoid'): 423,
#  np.str_('particularly'): 424,
#  np.str_('party'): 425,
#  np.str_('pass'): 426,
#  np.str_('patients'): 427,
#  np.str_('paul'): 428,
#  np.str_('payroll'): 429,
#  np.str_('people'): 430,
#  np.str_('personal'): 431,
#  np.str_('pic'): 432,
#  np.str_('picked'): 433,
#  np.str_('picking'): 434,
#  np.str_('pieces'): 435,
#  np.str_('pinterest'): 436,
#  np.str_('place'): 437,
#  np.str_('plan'): 438,
#  np.str_('playing'): 439,
#  np.str_('pocket'): 440,
#  np.str_('political'): 441,
#  np.str_('politics'): 442,
#  np.str_('poses'): 443,
#  np.str_('positive'): 444,
#  np.str_('possible'): 445,
#  np.str_('postured'): 446,
#  np.str_('power'): 447,
#  np.str_('practically'): 448,
#  np.str_('preemptive'): 449,
#  np.str_('preemptively'): 450,
#  np.str_('president'): 451,
#  np.str_('presidential'): 452,
#  np.str_('pretend'): 453,
#  np.str_('pretending'): 454,
#  np.str_('previously'): 455,
#  np.str_('principled'): 456,
#  np.str_('principles'): 457,
#  np.str_('print'): 458,
#  np.str_('pro'): 459,
#  np.str_('procedural'): 460,
#  np.str_('procedure'): 461,
#  np.str_('prominent'): 462,
#  np.str_('promising'): 463,
#  np.str_('protecting'): 464,
#  np.str_('proved'): 465,
#  np.str_('public'): 466,
#  np.str_('published'): 467,
#  np.str_('pure'): 468,
#  np.str_('push'): 469,
#  np.str_('putin'): 470,
#  np.str_('question'): 471,
#  np.str_('questions'): 472,
#  np.str_('quickly'): 473,
#  np.str_('radical'): 474,
#  np.str_('rally'): 475,
#  np.str_('ranks'): 476,
#  np.str_('rating'): 477,
#  np.str_('re'): 478,
#  np.str_('react'): 479,
#  np.str_('realdonaldtrump'): 480,
#  np.str_('reality'): 481,
#  np.str_('really'): 482,
#  np.str_('reason'): 483,
#  np.str_('recalls'): 484,
#  np.str_('recover'): 485,
#  np.str_('reddit'): 486,
#  np.str_('refused'): 487,
#  np.str_('reid'): 488,
#  np.str_('relevance'): 489,
#  np.str_('relief'): 490,
#  np.str_('remembered'): 491,
#  np.str_('remind'): 492,
#  np.str_('replaced'): 493,
#  np.str_('republican'): 494,
#  np.str_('republicans'): 495,
#  np.str_('resignation'): 496,
#  np.str_('respected'): 497,
#  np.str_('respond'): 498,
#  np.str_('results'): 499,
#  np.str_('retired'): 500,
#  np.str_('reveal'): 501,
#  np.str_('revelation'): 502,
#  np.str_('reversed'): 503,
#  np.str_('review'): 504,
#  np.str_('ride'): 505,
#  np.str_('rigged'): 506,
#  np.str_('right'): 507,
#  np.str_('ringing'): 508,
#  np.str_('risk'): 509,
#  np.str_('rodham'): 510,
#  np.str_('role'): 511,
#  np.str_('running'): 512,
#  np.str_('ryan'): 513,
#  np.str_('s'): 514,
#  np.str_('same'): 515,
#  np.str_('savage'): 516,
#  np.str_('says'): 517,
#  np.str_('scandal'): 518,
#  np.str_('scandals'): 519,
#  np.str_('scene'): 520,
#  np.str_('screwed'): 521,
#  np.str_('security'): 522,
#  np.str_('seemed'): 523,
#  np.str_('senator'): 524,
#  np.str_('senior'): 525,
#  np.str_('sent'): 526,
#  np.str_('server'): 527,
#  np.str_('setup'): 528,
#  np.str_('sexism'): 529,
#  np.str_('sexual'): 530,
#  np.str_('she'): 531,
#  np.str_('shillman'): 532,
#  np.str_('short'): 533,
#  np.str_('shove'): 534,
#  np.str_('shown'): 535,
#  np.str_('shrugged'): 536,
#  np.str_('sigh'): 537,
#  np.str_('slightest'): 538,
#  np.str_('smart'): 539,
#  np.str_('smell'): 540,
#  np.str_('smoke'): 541,
#  np.str_('sniveling'): 542,
#  np.str_('so'): 543,
#  np.str_('space'): 544,
#  np.str_('speaker'): 545,
#  np.str_('speakerryan'): 546,
#  np.str_('speaks'): 547,
#  np.str_('spectrum'): 548,
#  np.str_('spinelessness'): 549,
#  np.str_('spinmeisters'): 550,
#  np.str_('spouting'): 551,
#  np.str_('stage'): 552,
#  np.str_('staggering'): 553,
#  np.str_('stand'): 554,
#  np.str_('start'): 555,
#  np.str_('statement'): 556,
#  np.str_('states'): 557,
#  np.str_('stay'): 558,
#  np.str_('step'): 559,
#  np.str_('still'): 560,
#  np.str_('stored'): 561,
#  np.str_('stories'): 562,
#  np.str_('strange'): 563,
#  np.str_('strategy'): 564,
#  np.str_('stretch'): 565,
#  np.str_('struggle'): 566,
#  np.str_('stumbleupon'): 567,
#  np.str_('substance'): 568,
#  np.str_('such'): 569,
#  np.str_('sudden'): 570,
#  np.str_('suddenly'): 571,
#  np.str_('supporting'): 572,
#  np.str_('surprising'): 573,
#  np.str_('surreal'): 574,
#  np.str_('survival'): 575,
#  np.str_('t'): 576,
#  np.str_('table'): 577,
#  np.str_('tak'): 578,
#  np.str_('taking'): 579,
#  np.str_('talked'): 580,
#  np.str_('tape'): 581,
#  np.str_('targeting'): 582,
#  np.str_('television'): 583,
#  np.str_('tells'): 584,
#  np.str_('tenth'): 585,
#  np.str_('than'): 586,
#  np.str_('that'): 587,
#  np.str_('the'): 588,
#  np.str_('their'): 589,
#  np.str_('them'): 590,
#  np.str_('then'): 591,
#  np.str_('there'): 592,
#  np.str_('they'): 593,
#  np.str_('thing'): 594,
#  np.str_('this'): 595,
#  np.str_('those'): 596,
#  np.str_('thought'): 597,
#  np.str_('threat'): 598,
#  np.str_('through'): 599,
#  np.str_('throughout'): 600,
#  np.str_('thrown'): 601,
#  np.str_('tied'): 602,
#  np.str_('time'): 603,
#  np.str_('times'): 604,
#  np.str_('to'): 605,
#  np.str_('today'): 606,
#  np.str_('too'): 607,
#  np.str_('train'): 608,
#  np.str_('trapped'): 609,
#  np.str_('trash'): 610,
#  np.str_('truly'): 611,
#  np.str_('trump'): 612,
#  np.str_('truths'): 613,
#  np.str_('try'): 614,
#  np.str_('trying'): 615,
#  np.str_('tumblr'): 616,
#  np.str_('turned'): 617,
#  np.str_('twitter'): 618,
#  np.str_('two'): 619,
#  np.str_('ugly'): 620,
#  np.str_('unapologetic'): 621,
#  np.str_('uncomfortable'): 622,
#  np.str_('under'): 623,
#  np.str_('underway'): 624,
#  np.str_('unfavorable'): 625,
#  np.str_('unite'): 626,
#  np.str_('united'): 627,
#  np.str_('unprecedented'): 628,
#  np.str_('unscathed'): 629,
#  np.str_('until'): 630,
#  np.str_('up'): 631,
#  np.str_('us'): 632,
#  np.str_('used'): 633,
#  np.str_('usual'): 634,
#  np.str_('utter'): 635,
#  np.str_('value'): 636,
#  np.str_('vast'): 637,
#  np.str_('very'): 638,
#  np.str_('victory'): 639,
#  np.str_('violating'): 640,
#  np.str_('violation'): 641,
#  np.str_('vladimir'): 642,
#  np.str_('volumes'): 643,
#  np.str_('vote'): 644,
#  np.str_('voted'): 645,
#  np.str_('vytt49yvoe'): 646,
#  np.str_('wake'): 647,
#  np.str_('waking'): 648,
#  np.str_('want'): 649,
#  np.str_('wants'): 650,
#  np.str_('war'): 651,
#  np.str_('warned'): 652,
#  np.str_('warning'): 653,
#  np.str_('was'): 654,
#  np.str_('watching'): 655,
#  np.str_('way'): 656,
#  np.str_('wcvscg4a5i'): 657,
#  np.str_('weathered'): 658,
#  np.str_('weeks'): 659,
#  np.str_('weiner'): 660,
#  np.str_('well'): 661,
#  np.str_('went'): 662,
#  np.str_('were'): 663,
#  np.str_('what'): 664,
#  np.str_('whatever'): 665,
#  np.str_('when'): 666,
#  np.str_('where'): 667,
#  np.str_('whether'): 668,
#  np.str_('which'): 669,
#  np.str_('while'): 670,
#  np.str_('who'): 671,
#  np.str_('whole'): 672,
#  np.str_('whose'): 673,
#  np.str_('why'): 674,
#  np.str_('wikipedia'): 675,
#  np.str_('will'): 676,
#  np.str_('wing'): 677,
#  np.str_('wiretaps'): 678,
#  np.str_('wisconsin'): 679,
#  np.str_('with'): 680,
#  np.str_('within'): 681,
#  np.str_('without'): 682,
#  np.str_('women'): 683,
#  np.str_('word'): 684,
#  np.str_('world'): 685,
#  np.str_('would'): 686,
#  np.str_('wouldn'): 687,
#  np.str_('wound'): 688,
#  np.str_('wreck'): 689,
#  np.str_('wreckage'): 690,
#  np.str_('writer'): 691,
#  np.str_('wrong'): 692,
#  np.str_('years'): 693,
#  np.str_('york'): 694,
#  np.str_('you'): 695,
#  np.str_('your'): 696,
#  np.str_('zero'): 697}
